# %%
import requests
import json

# %%
items_url = 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'

# %%
items_data = requests.get(items_url)

# %%
items_data.text
# Out:
# '{"resultCode":"success","result":{"etfItemList":[{"itemcode":"069500","etfTabCode":1,"itemname":"KODEX 200","nowVal":26600,"risefall":"2","changeVal":345,"changeRate":1.31,"nav":26649.0,"threeMonthEarnRate":-7.3506,"quant":2910325,"amonut":77082,"marketSum":50327},{"itemcode":"122630","etfTabCode":3,"itemname":"KODEX 레버리지","nowVal":11005,"risefall":"2","changeVal":280,"changeRate":2.61,"nav":11052.0,"threeMonthEarnRate":-19.663,"quant":39585708,"amonut":431524,"marketSum":31254},{"itemcode":"102110","etfTabCode":1,"itemname":"TIGER 200","nowVal":26600,"risefall":"2","changeVal":335,"changeRate":1.28,"nav":26648.0,"threeMonthEarnRate":-7.263,"quant":595971,"amonut":15773,"marketSum":27903},{"itemcode":"153130","etfTabCode":6,"itemname":"KODEX 단기채권","nowVal":102305,"risefall":"5","changeVal":-5,"changeRate":0.0,"nav":102310.0,"threeMonthEarnRate":0.3875,"quant":28695,"amonut":2935,"marketSum":20865},{"itemcode":"252670","etfTabCode":3,"itemname":"KODEX 200선물인버스2X","nowVal":6120,"risef
# ...
