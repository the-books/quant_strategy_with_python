# %%
import time
import QuantStocks
import QuantFS
import pandas as pd
import requests

# %%
stocks_path = './data/stocks.tsv'
code_data = QuantStocks.make_stocks(stocks_path)

code_data
# Out:
#          종목코드     기업명
# 0     A060310      3S
# 1     A095570  AJ네트웍스
# 2     A006840   AK홀딩스
# 3     A054620  APS홀딩스
# 4     A265520   AP시스템
# ...       ...     ...
# 2352  A189980  흥국에프엔비
# 2353  A000540    흥국화재
# 2354  A003280    흥아해운
# 2355  A037440      희림
# 2356  A238490      힘스
#
# [2357 rows x 2 columns]

# %%
for num, code in enumerate(code_data['종목코드']):
    try:
        print(num, code)
        time.sleep(1)

        try:
            fs_df = QuantFS.make_fs_dataframe(code)
        except requests.exceptions.Timeout:
            tiem.sleep(60)
            fs_df = QuantFS.make_fs_dataframe(code)

        fs_df_changed = QuantFS.change_df(code, fs_df)

        if num == 0:
            total_fs = fs_df_changed
        else:
            total_fs = pd.concat([total_fs, fs_df_changed])
    except ValueError:
        continue
    except KeyError:
        continue
# Out:
# 0 A060310
# 1 A095570
# 2 A006840
# 3 A054620
# 4 A265520
# 5 A211270
# 6 A027410
# 7 A282330
# 8 A138930
# 9 A001460
# 10 A001040
# 11 A079160
# 12 A035760
# 13 A000120
# 14 A011150
# 15 A097950
# 16 A051500
# 17 A058820
# 18 A023460
# 19 A065770
# 20 A083660
# 21 A000590
# 22 A012030
# 23 A322780
# 24 A016610
# 25 A005830
# 26 A000990
# 27 A139130
# 28 A068790
# 29 A004840
# 30 A241520
# 31 A155660
# 32 A069730
# 33 A017940
# 34 A245620
# 35 A037370
# 36 A079190
# 37 A007700
# 38 A130500
# 39 A114090
# 40 A900290
# 41 A078930
# 42 A083450
# 43 A006360
# 44 A001250
# 45 A007070
# 46 A028150
# 47 A045890
# 48 A078150
# 49 A012630
# 50 A039570
# 51 A089470
# 52 A294870
# 53 A011200
# 54 A036640
# 55 A082740
# 56 A299170
# 57 A335890
# 58 A335870
# 59 A276920
# 60 A095340
# 61 A099520
# 62 A175330
# 63 A950170
# 64 A234080
# 65 A067290
# 66 A001060
# 67 A096760
# 68 A035900
# 69 A024840
# 70 A105560
# 71 A024120
# 72 A021320
# 73 A036670
# 74 A009440
# 75 A112190
# 76 A119650
# ...

# %%
total_fs
# Out:
#         2016/12                                                           \
#           당기순이익      매출액       부채    영업이익 영업활동으로인한현금흐름       자본       자산
# A060310     NaN      NaN      NaN     NaN          NaN      NaN      NaN
# A095570   171.0  12539.0  16538.0   619.0      -1867.0   4275.0  20813.0
# A006840  1333.0  29218.0  17305.0  2137.0       3183.0  10114.0  27419.0
# A054620   275.0    243.0   3593.0   -23.0        846.0   2070.0   5662.0
# A265520     NaN      NaN      NaN     NaN          NaN      NaN      NaN
# ...         ...      ...      ...     ...          ...      ...      ...
# A058730   123.0   1571.0    531.0   158.0        130.0   1040.0   1571.0
# A023590  1920.0  11534.0  79370.0  2534.0      -3574.0  16076.0  95446.0
# A032190  1741.0  13784.0  81852.0  2642.0      -3453.0  17160.0  99012.0
# A323350     NaN      NaN      NaN     NaN          NaN      NaN      NaN
# A068240    68.0    742.0    989.0    92.0       -245.0   1391.0   2380.0
#
# ...

# %%
total_fs.loc['A060310']
# Out:
# 2016/12  당기순이익          NaN
#          매출액            NaN
#          부채             NaN
#          영업이익           NaN
#          영업활동으로인한현금흐름   NaN
#                          ..
# 2020/02  부채             NaN
#          영업이익           NaN
#          영업활동으로인한현금흐름   NaN
#          자본             NaN
#          자산             NaN
# Name: A060310, Length: 154, dtype: float64

# %%
total_fs.to_excel(r'.\data\재무제표데이터.xlsx')

# %%
total_fs
# Out:
#         2016/12                                                           \
#           당기순이익      매출액       부채    영업이익 영업활동으로인한현금흐름       자본       자산
# A060310     NaN      NaN      NaN     NaN          NaN      NaN      NaN
# A095570   171.0  12539.0  16538.0   619.0      -1867.0   4275.0  20813.0
# A006840  1333.0  29218.0  17305.0  2137.0       3183.0  10114.0  27419.0
# A054620   275.0    243.0   3593.0   -23.0        846.0   2070.0   5662.0
# A265520     NaN      NaN      NaN     NaN          NaN      NaN      NaN
# ...         ...      ...      ...     ...          ...      ...      ...
# A058730   123.0   1571.0    531.0   158.0        130.0   1040.0   1571.0
# A023590  1920.0  11534.0  79370.0  2534.0      -3574.0  16076.0  95446.0
# A032190  1741.0  13784.0  81852.0  2642.0      -3453.0  17160.0  99012.0
# A323350     NaN      NaN      NaN     NaN          NaN      NaN      NaN
# A068240    68.0    742.0    989.0    92.0       -245.0   1391.0   2380.0
#
# ...
